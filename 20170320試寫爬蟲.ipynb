# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

res = requests.get("http://www.baseball-reference.com/players/l/landiji01.shtml")
soup = BeautifulSoup(res.text, "lxml")

data = []
table = soup.find('table', attrs={'class':'stats_table'})
table_body = table.find('tbody')

rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele]) # Get rid of empty values
    
frame = pd.DataFrame(data,index=p_head)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\core\internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    3928         blocks = form_blocks(arrays, names, axes)
# -> 3929         mgr = BlockManager(blocks, axes)
#    3930         mgr._consolidate_inplace()
#
# D:\Anaconda3\lib\site-packages\pandas\core\internals.py in __init__(self, blocks, axes, do_integrity_check, fastpath)
#    2536         if do_integrity_check:
# -> 2537             self._verify_integrity()
#    2538
#
# D:\Anaconda3\lib\site-packages\pandas\core\internals.py in _verify_integrity(self)
#    2746             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# -> 2747                 construction_error(tot_items, block.shape[1:], self.axes)
#    2748         if len(self.items) != tot_items:
#
# ...

# %%
frame.head
# Out:
# <bound method NDFrame.head of                                                    0        1     2     3   \
# 0                                                  18  CHW-min     D    92
# 1                                                  19  CHW-min     A   128
# 2   Did not play in major or minor leagues (Milita...     None  None  None
# 3   Did not play in major or minor leagues (Milita...     None  None  None
# 4                                                  22  CHW-min  AA,A   105
# 5                                                  23  CHW-min   AAA    37
# 6                                                  23      CHW    AL    96
# 7                                                  24      CHW    AL   142
# 8                                                  25      CHW    AL   149
# 9                                                  26      CHW    AL   148
# 10                                                 27      CHW    AL   140
# ...

# %%
frame
# Out:
#                                                    0        1     2     3   \
# 0                                                  18  CHW-min     D    92
# 1                                                  19  CHW-min     A   128
# 2   Did not play in major or minor leagues (Milita...     None  None  None
# 3   Did not play in major or minor leagues (Milita...     None  None  None
# 4                                                  22  CHW-min  AA,A   105
# 5                                                  23  CHW-min   AAA    37
# 6                                                  23      CHW    AL    96
# 7                                                  24      CHW    AL   142
# 8                                                  25      CHW    AL   149
# 9                                                  26      CHW    AL   148
# 10                                                 27      CHW    AL   140
# ...

# %%
table_head = table.find('thead')

p_head=[]
rows = table_head.find_all('tr')
for row in rows:
    cols = row.find_all('th')
    cols = [ele.text.strip() for ele in cols]
    p_head.append([ele for ele in cols if ele])

# %%
aph = np.array(p_head)

# %%
aph
# Out:
# array([<generator object <genexpr> at 0x000000000A5F8678>], dtype=object)

# %%
p_head
# Out:
# [['Year',
#   'Age',
#   'Tm',
#   'Lg',
#   'G',
#   'PA',
#   'AB',
#   'R',
#   'H',
#   '2B',
#   '3B',
#   'HR',
#   'RBI',
#   'SB',
#   'CS',
#   'BB',
#   'SO',
#   'BA',
#   'OBP',
#   'SLG',
#   'OPS',
#   'OPS+',
#   'TB',
#   'GDP',
#   'HBP',
#   'SH',
#   'SF',
#   'IBB',
#   'Pos',
#   'Awards']]

# %%
import numpy as np

# %%
df = pd.DataFrame(index=p_head)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [Year, Age, Tm, Lg, G, PA, AB, R, H, 2B, 3B, HR, RBI, SB, CS, BB, SO, BA, OBP, SLG, OPS, OPS+, TB, GDP, HBP, SH, SF, IBB, Pos, Awards]
