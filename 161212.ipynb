# %%
import pandas as pd

# %%
pd.read_csv('車輪餅與他的產地-report.csv')
# Out:
#                                    #   抹茶  冰淇淋   咖哩    臭豆腐  義大利肉醬   叉燒   麻糬  \
# 0   ecd7e70ab6e30276207cccb35e1c1675  NaN  NaN   咖哩  義大利肉醬    NaN   叉燒  NaN
# 1   92e4c35395489f2eac599558c3d35625   抹茶  NaN  NaN    NaN    NaN  NaN  NaN
# 2   8c4254a77f7745a6a48020be98f14f57   抹茶  冰淇淋   咖哩    NaN  義大利肉醬   叉燒   麻糬
# 3   1a560429eed18f60d0218381710cb797  NaN  NaN  NaN    NaN    NaN  NaN   麻糬
# 4   413ea0d5d035512c431d386647ba47cf   抹茶  冰淇淋  NaN    臭豆腐    NaN  NaN   麻糬
# 5   c0837fb1057aeb81d76b7d8dbec6dba8   抹茶  冰淇淋  NaN    臭豆腐    NaN   叉燒  NaN
# 6   c301427b883e1347b4cc664cce9ab801   抹茶  NaN  NaN    NaN    NaN  NaN  NaN
# 7   f6b46b35f719ac5ec3fb1b6ea112fb54  NaN  冰淇淋  NaN    NaN    NaN  NaN   麻糬
# 8   d0d942a8d6df14dcddb04ca725ed8730   抹茶  冰淇淋  NaN    NaN    NaN  NaN   麻糬
# 9   0b9c7c4da936a2c624d805c7823984db  NaN  NaN   咖哩    臭豆腐  義大利肉醬  NaN  NaN
# 10  00a329501c32c2c74871f20783d39367  NaN  NaN   咖哩    臭豆腐  義大利肉醬  NaN  NaN
# ...

# %%
from sympy import *
from sympy.abc import x
init_printing()

# %%
def 泰勒():
    f= sympify(cos(x))
    p=0
    n=4
    return series(f,x,p,n).removeO()

# %%
泰勒()
# Out:
#    2
#   x
# - ── + 1
#   2

# %%
k=input("你掉的是1.金湯匙、2.銀湯匙還是3.破湯匙啊？")
k=int(k);

while(k !=0):
    if(k==1):
        print("你不誠實~你才沒有掉過湯匙")
    if(k==2):
        print("你不誠實~你才沒有掉過湯匙")
    if(k==3):
        print("請找炎龍老師領回你的破湯匙")
        break;
# Out:
# 你掉的是1.金湯匙、2.銀湯匙還是3.破湯匙啊？1
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# 你不誠實~你才沒有掉過湯匙
# ...
